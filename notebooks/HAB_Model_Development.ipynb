# %% [markdown]
# # HAB (Harmful Algal Bloom) Prediction Model Development
#
# This notebook demonstrates the development and training of the HAB prediction model for FjordSight's salmon farming operations.
#
# ## Objectives
# - Load and explore environmental sensor data
# - Engineer features for HAB prediction
# - Train and evaluate machine learning models
# - Deploy model for real-time predictions
